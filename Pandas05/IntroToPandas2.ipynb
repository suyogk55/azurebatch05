# %%
import pandas as pd

# %%
df_orders = pd.read_csv('orders.txt')

# %%
df_orders
# Out:
#             order_id order_date      customer_name           city  \
# 0     CA-2018-100006   9/7/2018        Dennis Kane  New York City
# 1     CA-2018-100090   7/8/2018         Ed Braxton  San Francisco
# 2     CA-2018-100293  3/14/2018   Neil Französisch   Jacksonville
# 3     CA-2018-100328  1/28/2018    Jasper Cacioppo  New York City
# 4     CA-2018-100363   4/8/2018        Jim Mitchum       Glendale
# ...              ...        ...                ...            ...
# 5011  US-2021-169488   9/7/2021       Allen Armold     Providence
# 5012  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5013  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5014  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
# 5015  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df = df_orders.dropna()
df.groupby('profit').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
df_orders.head(5)
# Out:
#          order_id order_date     customer_name           city  \
# 0  CA-2018-100006   9/7/2018       Dennis Kane  New York City
# 1  CA-2018-100090   7/8/2018        Ed Braxton  San Francisco
# 2  CA-2018-100293  3/14/2018  Neil Französisch   Jacksonville
# 3  CA-2018-100328  1/28/2018   Jasper Cacioppo  New York City
# 4  CA-2018-100363   4/8/2018       Jim Mitchum       Glendale
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3  Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4  Office Supplies  OFF-FA-10000611    2.368    0.8288

# %%
df_orders.tail(5)
# Out:
#             order_id order_date      customer_name          city  \
# 5011  US-2021-169488   9/7/2021       Allen Armold    Providence
# 5012  US-2021-169502  8/28/2021  Matthew Grinstein     Milwaukee
# 5013  US-2021-169502  8/28/2021  Matthew Grinstein     Milwaukee
# 5014  US-2021-169551   7/7/2021          Rob Lucas  Philadelphia
# 5015  US-2021-169551   7/7/2021          Rob Lucas  Philadelphia
#
#              category       product_id  sales   profit
# 5011  Office Supplies  OFF-PA-10000157  39.96  18.7812
# 5012  Office Supplies  OFF-AP-10001947  91.60  26.5640
# 5013  Office Supplies  OFF-AP-10001947  91.60  26.5640
# 5014        Furniture  FUR-BO-10001519  87.21 -45.3492
# 5015        Furniture  FUR-BO-10001519  87.21 -45.3492

# %%
#select a single column
city = df_orders['city']

# %%
city
# Out:
# 0       New York City
# 1       San Francisco
# 2        Jacksonville
# 3       New York City
# 4            Glendale
#             ...
# 5009          Seattle
# 5010          Elkhart
# 5011       Providence
# 5012        Milwaukee
# 5013     Philadelphia
# Name: city, Length: 5014, dtype: object

# %%
#select multiple columns
subset = df_orders[['customer_name','city']]

# %%
subset
# Out:
#           customer_name           city
# 0           Dennis Kane  New York City
# 1            Ed Braxton  San Francisco
# 2      Neil Französisch   Jacksonville
# 3       Jasper Cacioppo  New York City
# 4           Jim Mitchum       Glendale
# ...                 ...            ...
# 5009      Jack O'Briant        Seattle
# 5010     Lena Hernandez        Elkhart
# 5011       Allen Armold     Providence
# 5012  Matthew Grinstein      Milwaukee
# 5013          Rob Lucas   Philadelphia
#
# [5014 rows x 2 columns]

# %%
print(type(subset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#select rows by condition where we have the profit more than 200

profit_orders = df_orders[df_orders['profit']>200]
profit_orders
# Out:
#             order_id  order_date     customer_name              city  \
# 45    CA-2018-103100  12/20/2018     Adrian Barton      Indianapolis
# 95    CA-2018-106726   12/6/2018    Roland Schwarz       Los Angeles
# 154   CA-2018-111192   7/30/2018       Tom Stivers           Seattle
# 212   CA-2018-116246   9/12/2018        Luke Weiss     New York City
# 215   CA-2018-116666    5/8/2018     Kean Thornton      Philadelphia
# ...              ...         ...               ...               ...
# 4708  US-2020-163881  11/24/2020          Sung Pak       Los Angeles
# 4710  US-2020-164196  11/11/2020  Alejandro Savely       Noblesville
# 4735  US-2021-102183   8/21/2021         Pete Kriz     New York City
# 4818  US-2021-118941   8/12/2021     Brenda Bowman          Columbia
# 4887  US-2021-135013   7/24/2021       Harold Ryan  Huntington Beach
#
#              category       product_id     sales     profit
# 45    Office Supplies  OFF-BI-10004600  1103.970   496.7865
# ...

# %%
display(profit_orders)
# Out:
#             order_id  order_date     customer_name              city  \
# 45    CA-2018-103100  12/20/2018     Adrian Barton      Indianapolis
# 95    CA-2018-106726   12/6/2018    Roland Schwarz       Los Angeles
# 154   CA-2018-111192   7/30/2018       Tom Stivers           Seattle
# 212   CA-2018-116246   9/12/2018        Luke Weiss     New York City
# 215   CA-2018-116666    5/8/2018     Kean Thornton      Philadelphia
# ...              ...         ...               ...               ...
# 4708  US-2020-163881  11/24/2020          Sung Pak       Los Angeles
# 4710  US-2020-164196  11/11/2020  Alejandro Savely       Noblesville
# 4735  US-2021-102183   8/21/2021         Pete Kriz     New York City
# 4818  US-2021-118941   8/12/2021     Brenda Bowman          Columbia
# 4887  US-2021-135013   7/24/2021       Harold Ryan  Huntington Beach
#
#              category       product_id     sales     profit
# 45    Office Supplies  OFF-BI-10004600  1103.970   496.7865
# ...

# %%
df_orders.count()
# Out:
# order_id         5012
# order_date       5012
# customer_name    5012
# city             5012
# category         5012
# product_id       5012
# sales            5012
# profit           5012
# dtype: int64

# %%
#in case you want to see the sample data
df_orders.sample(n=5)
# Out:
#             order_id  order_date       customer_name           city  \
# 1240  CA-2019-132941   5/25/2019  Muhammed MacIntyre    Haltom City
# 1416  CA-2019-145835   5/13/2019          Ben Ferrer        Chicago
# 134   CA-2018-109932   12/9/2018    Victoria Pisteka    Brownsville
# 3901  CA-2021-154935  12/24/2021         Andy Reiter  New York City
# 1584  CA-2019-158792  12/26/2019        Brian Dahlen       Lawrence
#
#              category       product_id   sales   profit
# 1240  Office Supplies  OFF-PA-10002160  32.368  11.7334
# 1416  Office Supplies  OFF-FA-10002280  16.000   5.6000
# 134   Office Supplies  OFF-PA-10001804  10.688   3.7408
# 3901  Office Supplies  OFF-BI-10003708  17.880   5.5875
# 1584  Office Supplies  OFF-FA-10002815  22.200  10.4340

# %%
#top sales or top lowest sales
# df_orders.nlargest(10,'sales')
#df_orders.nsmallest(10,'sales')
#for profits
# df_orders.nsmallest(10,'profit')
df_orders.nlargest(10,'profit')
# Out:
#             order_id  order_date     customer_name            city  \
# 4131  CA-2021-166709  11/17/2021      Hunter Lopez          Newark
# 1973  CA-2020-117121  12/17/2020     Adrian Barton         Detroit
# 552   CA-2018-145541  12/14/2018  Tom Boeckenhauer   New York City
# 3526  CA-2021-135909  10/13/2021         Jane Waco      Sacramento
# 4735  US-2021-102183   8/21/2021         Pete Kriz   New York City
# 228   CA-2018-117639   5/21/2018  Mitch Willingham  Virginia Beach
# 1624  CA-2019-162782   2/21/2019      Pierre Wener        Columbia
# 545   CA-2018-144624  11/19/2018       John Murray       Jamestown
# 4492  US-2019-163825   6/16/2019    Lena Creighton   New York City
# 3489  CA-2021-133865    5/8/2021   Penelope Sewall     Los Angeles
#
#              category       product_id      sales     profit
# 4131       Technology  TEC-CO-10004722  10499.970  5039.9856
# 1973  Office Supplies  OFF-BI-10000545   9892.740  4946.3700
# ...

# %%
#selecting unique data
df_unique = df_orders.drop_duplicates()

# %%
df_unique.count()
# Out:
# order_id         5009
# order_date       5009
# customer_name    5009
# city             5009
# category         5009
# product_id       5009
# sales            5009
# profit           5009
# dtype: int64

# %%
df_orders.count()
# Out:
# order_id         5014
# order_date       5014
# customer_name    5014
# city             5014
# category         5014
# product_id       5014
# sales            5014
# profit           5014
# dtype: int64

# %%
df_unique.tail(5)
# Out:
#             order_id order_date      customer_name          city  \
# 5009  US-2021-168802  11/3/2021      Jack O'Briant       Seattle
# 5010  US-2021-169320  7/23/2021     Lena Hernandez       Elkhart
# 5011  US-2021-169488   9/7/2021       Allen Armold    Providence
# 5012  US-2021-169502  8/28/2021  Matthew Grinstein     Milwaukee
# 5014  US-2021-169551   7/7/2021          Rob Lucas  Philadelphia
#
#              category       product_id   sales   profit
# 5009  Office Supplies  OFF-BI-10002393  18.368   5.9696
# 5010  Office Supplies  OFF-AR-10003602  11.680   5.4896
# 5011  Office Supplies  OFF-PA-10000157  39.960  18.7812
# 5012  Office Supplies  OFF-AP-10001947  91.600  26.5640
# 5014        Furniture  FUR-BO-10001519  87.210 -45.3492

# %%
#drop column 
df_selective = df_orders.drop(columns='profit')
df_selective
# Out:
#             order_id order_date      customer_name           city  \
# 0     CA-2018-100006   9/7/2018        Dennis Kane  New York City
# 1     CA-2018-100090   7/8/2018         Ed Braxton  San Francisco
# 2     CA-2018-100293  3/14/2018   Neil Französisch   Jacksonville
# 3     CA-2018-100328  1/28/2018    Jasper Cacioppo  New York City
# 4     CA-2018-100363   4/8/2018        Jim Mitchum       Glendale
# ...              ...        ...                ...            ...
# 5011  US-2021-169488   9/7/2021       Allen Armold     Providence
# 5012  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5013  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5014  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
# 5015  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
#
#              category       product_id    sales
# 0          Technology  TEC-PH-10002075  377.970
# 1           Furniture  FUR-TA-10003715  502.488
# ...

# %%
# to remove null values or rows with no data
df_data = df_orders.dropna(how='all')

# %%
df_data.count()
# Out:
# order_id         5014
# order_date       5014
# customer_name    5014
# city             5014
# category         5014
# product_id       5014
# sales            5014
# profit           5014
# dtype: int64

# %%
df_orders.count()
# Out:
# order_id         5014
# order_date       5014
# customer_name    5014
# city             5014
# category         5014
# product_id       5014
# sales            5014
# profit           5014
# dtype: int64

# %%
df_orders.to_csv('orders_new.csv')

# %%
df_new = pd.read_csv('orders_new.csv')

# %%
df_data = df_new.dropna(how='any')
df_data.count()
# Out:
# Unnamed: 0       5014
# order_id         5014
# order_date       5014
# customer_name    5014
# city             5014
# category         5014
# product_id       5014
# sales            5014
# profit           5014
# dtype: int64

# %%
df_new.count()
# Out:
# Unnamed: 0       5016
# order_id         5014
# order_date       5014
# customer_name    5014
# city             5014
# category         5014
# product_id       5014
# sales            5014
# profit           5014
# dtype: int64

# %%
#Data Manipulation
#Add or remove columns
df_new['prod_id'] = df_new['product_id']

# %%
df_new
# Out:
#       Unnamed: 0        order_id order_date      customer_name           city  \
# 0              0  CA-2018-100006   9/7/2018        Dennis Kane  New York City
# 1              1  CA-2018-100090   7/8/2018         Ed Braxton  San Francisco
# 2              2  CA-2018-100293  3/14/2018   Neil Französisch   Jacksonville
# 3              3  CA-2018-100328  1/28/2018    Jasper Cacioppo  New York City
# 4              4  CA-2018-100363   4/8/2018        Jim Mitchum       Glendale
# ...          ...             ...        ...                ...            ...
# 5011        5011  US-2021-169488   9/7/2021       Allen Armold     Providence
# 5012        5012  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5013        5013  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5014        5014  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
# 5015        5015  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
#
# ...

# %%
df_new = df_new.drop('prod_id',axis=1)

# %%
df_new
# Out:
#       Unnamed: 0        order_id order_date      customer_name           city  \
# 0              0  CA-2018-100006   9/7/2018        Dennis Kane  New York City
# 1              1  CA-2018-100090   7/8/2018         Ed Braxton  San Francisco
# 2              2  CA-2018-100293  3/14/2018   Neil Französisch   Jacksonville
# 3              3  CA-2018-100328  1/28/2018    Jasper Cacioppo  New York City
# 4              4  CA-2018-100363   4/8/2018        Jim Mitchum       Glendale
# ...          ...             ...        ...                ...            ...
# 5011        5011  US-2021-169488   9/7/2021       Allen Armold     Providence
# 5012        5012  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5013        5013  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5014        5014  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
# 5015        5015  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
#
# ...

# %%
#rename the columns
df_new = df_new.rename(columns={'category':'department'})
df_new
# Out:
#       Unnamed: 0        order_id order_date      customer_name           city  \
# 0              0  CA-2018-100006   9/7/2018        Dennis Kane  New York City
# 1              1  CA-2018-100090   7/8/2018         Ed Braxton  San Francisco
# 2              2  CA-2018-100293  3/14/2018   Neil Französisch   Jacksonville
# 3              3  CA-2018-100328  1/28/2018    Jasper Cacioppo  New York City
# 4              4  CA-2018-100363   4/8/2018        Jim Mitchum       Glendale
# ...          ...             ...        ...                ...            ...
# 5011        5011  US-2021-169488   9/7/2021       Allen Armold     Providence
# 5012        5012  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5013        5013  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5014        5014  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
# 5015        5015  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
#
# ...

# %%
df_na=df_new.isnull()

# %%
df_na
# Out:
#       Unnamed: 0  order_id  order_date  customer_name   city  department  \
# 0          False     False       False          False  False       False
# 1          False     False       False          False  False       False
# 2          False     False       False          False  False       False
# 3          False     False       False          False  False       False
# 4          False     False       False          False  False       False
# ...          ...       ...         ...            ...    ...         ...
# 5011       False     False       False          False  False       False
# 5012       False     False       False          False  False       False
# 5013       False     False       False          False  False       False
# 5014       False     False       False          False  False       False
# 5015       False     False       False          False  False       False
#
#       product_id  sales  profit
# 0          False  False   False
# ...

# %%
df_new = df_na.dropna()

# %%
df_new.count()
# Out:
# Unnamed: 0       5016
# order_id         5016
# order_date       5016
# customer_name    5016
# city             5016
# department       5016
# product_id       5016
# sales            5016
# profit           5016
# dtype: int64

# %%
df_orders['new_name']= df_orders['customer_name'] +':'+ df_orders['city']

# %%
df_orders
# Out:
#             order_id order_date      customer_name           city  \
# 0     CA-2018-100006   9/7/2018        Dennis Kane  New York City
# 1     CA-2018-100090   7/8/2018         Ed Braxton  San Francisco
# 2     CA-2018-100293  3/14/2018   Neil Französisch   Jacksonville
# 3     CA-2018-100328  1/28/2018    Jasper Cacioppo  New York City
# 4     CA-2018-100363   4/8/2018        Jim Mitchum       Glendale
# ...              ...        ...                ...            ...
# 5011  US-2021-169488   9/7/2021       Allen Armold     Providence
# 5012  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5013  US-2021-169502  8/28/2021  Matthew Grinstein      Milwaukee
# 5014  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
# 5015  US-2021-169551   7/7/2021          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit  \
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...
